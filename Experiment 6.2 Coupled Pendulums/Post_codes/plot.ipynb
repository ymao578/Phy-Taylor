# %%
# %matplotlib inline

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
import re
import pickle
import tensorflow as tf
import numpy as np 
import PhyAct as pha

# %%
##load data############################################################################################################
Xtest = np.matrix(np.loadtxt("../post/testdata1/OOscillatorsns_test_x.csv",delimiter=',', dtype=np.float64));
Ytest = np.matrix(np.loadtxt("../post/testdata1/OOscillatorsns_test_y.csv",delimiter=',', dtype=np.float64));
#######################################################################################################################

# %%
##trure data###########################################################################################################
ti = 500 ##testing point
tLen = 150  ##testing length
Ycom = np.transpose(Ytest[(ti):(ti+tLen),:])
#######################################################################################################################

# %%
##testng data##########################################################################################################
t = np.arange(tLen)
t = np.reshape(t,(1,tLen))

t = t + 500

Y1_com = Ycom[0,:].flatten()
Y2_com = Ycom[1,:].flatten()
Y3_com = Ycom[2,:].flatten()
Y4_com = Ycom[3,:].flatten()
Y5_com = Ycom[4,:].flatten()
Y6_com = Ycom[5,:].flatten()

t = t.flatten()
Y1_com = (np.asarray(Y1_com)).flatten()
Y2_com = (np.asarray(Y2_com)).flatten()
Y3_com = (np.asarray(Y3_com)).flatten()
Y4_com = (np.asarray(Y4_com)).flatten()
Y5_com = (np.asarray(Y5_com)).flatten()
Y6_com = (np.asarray(Y6_com)).flatten()
###########################################################################################################################################

# %%
##load DNN data############################################################################################################
VVbY1 = np.loadtxt("../post/vvbx1.csv",delimiter=',', dtype=np.float64);
VVbY2 = np.loadtxt("../post/vvbx2.csv",delimiter=',', dtype=np.float64);
VVbY3 = np.loadtxt("../post/vvbx3.csv",delimiter=',', dtype=np.float64);
VVbY4 = np.loadtxt("../post/vvbv1.csv",delimiter=',', dtype=np.float64);
VVbY5 = np.loadtxt("../post/vvbv2.csv",delimiter=',', dtype=np.float64);
VVbY6 = np.loadtxt("../post/vvbv3.csv",delimiter=',', dtype=np.float64);
##

# %%
##load Knowlede_alpha data############################################################################################################
VVaY1 = np.loadtxt("../post/vvax1.csv",delimiter=',', dtype=np.float64);
VVaY2 = np.loadtxt("../post/vvax2.csv",delimiter=',', dtype=np.float64);
VVaY3 = np.loadtxt("../post/vvax3.csv",delimiter=',', dtype=np.float64);
VVaY4 = np.loadtxt("../post/vvav1.csv",delimiter=',', dtype=np.float64);
VVaY5 = np.loadtxt("../post/vvav2.csv",delimiter=',', dtype=np.float64);
VVaY6 = np.loadtxt("../post/vvav3.csv",delimiter=',', dtype=np.float64);
##

# %%
##load Knowlede_gamma data############################################################################################################
VVdY1 = np.loadtxt("../post/vvdx1.csv",delimiter=',', dtype=np.float64);
VVdY2 = np.loadtxt("../post/vvdx2.csv",delimiter=',', dtype=np.float64);
VVdY3 = np.loadtxt("../post/vvdx3.csv",delimiter=',', dtype=np.float64);
VVdY4 = np.loadtxt("../post/vvdv1.csv",delimiter=',', dtype=np.float64);
VVdY5 = np.loadtxt("../post/vvdv2.csv",delimiter=',', dtype=np.float64);
VVdY6 = np.loadtxt("../post/vvdv3.csv",delimiter=',', dtype=np.float64);
##

# %%
plt.figure(figsize= (9.5, 6))
plt.plot(t, VVbY1, linewidth=3, label = "FDNN", color='blue')
plt.plot(t, VVdY1, linewidth=3, label = "Phy-Taylor 1", color='lime')
plt.plot(t, VVaY1, linewidth=3, label = "Phy-Taylor 2", color='red')
plt.plot(t, Y1_com, linewidth=3, label = "Ground Truth", color='black')
plt.xlabel("Time k", fontsize=20)
plt.ylabel(r'$\theta_1 (k)$', fontsize=20)
plt.title("(c)", fontsize=25, fontweight='bold')
plt.legend()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20),
plt.rc('legend',fontsize=20) 
plt.grid()
plt.xlim([500, 650])
plt.ylim([-0.65, 0.80])
plt.savefig('ca.pdf', dpi=0.1)
plt.show()

# %%
plt.figure(figsize= (9.5, 6))
plt.plot(t, VVbY2, linewidth=3, label = "FDNN", color='blue')
plt.plot(t, VVdY2, linewidth=3, label = "Phy-Taylor 1", color='lime')
plt.plot(t, VVaY2, linewidth=3, label = "Phy-Taylor 2", color='red')
plt.plot(t, Y2_com, linewidth=3, label = "Ground Truth", color='black')
plt.xlabel("Time k", fontsize=20)
plt.ylabel(r'$\theta_2(k)$', fontsize=20)
plt.title("(d)", fontsize=25, fontweight='bold')
plt.legend()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.rc('legend',fontsize=20) 
plt.ylim([-2.5, 2.35])
plt.grid()
plt.xlim([500, 650])
plt.savefig('cb.pdf', dpi=0.1)
plt.show()

# %%
plt.figure(figsize= (9.5, 6))
plt.plot(t, VVbY3, linewidth=3, label = "FDNN", color='blue')
plt.plot(t, VVdY3, linewidth=3, label = "Phy-Taylor 1", color='lime')
plt.plot(t, VVaY3, linewidth=3, label = "Phy-Taylor 2", color='red')
plt.plot(t, Y1_com, linewidth=3, label = "Ground Truth", color='black')
plt.xlabel("Time k", fontsize=20)
plt.ylabel(r'$\theta_3(k)$', fontsize=20)
plt.title("(e)", fontsize=25, fontweight='bold')
plt.legend()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.rc('legend',fontsize=20) 
plt.ylim([-0.7, 0.85])
plt.grid()
plt.xlim([500, 650])
plt.savefig('cc.pdf', dpi=0.1)
plt.show()

# %%
plt.figure(figsize= (9.5, 6))
plt.plot(t, VVbY4, linewidth=3, label = "FDNN", color='blue')
plt.plot(t, VVdY4, linewidth=3, label = "Phy-Taylor 1", color='lime')
plt.plot(t, VVaY4, linewidth=3, label = "Phy-Taylor 2", color='red')
plt.plot(t, Y4_com, linewidth=3, label = "Ground Truth", color='black')
plt.xlabel("Time k", fontsize=20)
plt.ylabel(r'$\upsilon_1(k)$', fontsize=20)
plt.title("(f)", fontsize=25, fontweight='bold')
plt.legend()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.rc('legend',fontsize=20) 
plt.ylim([-5.5, 5])
plt.grid()
plt.xlim([500, 650])
plt.savefig('cd.pdf', dpi=0.1)
plt.show()

# %%
plt.figure(figsize= (9.5, 6))
plt.plot(t, VVbY5, linewidth=3, label = "FDNN", color='blue')
plt.plot(t, VVdY5, linewidth=3, label = "Phy-Taylor 1", color='lime')
plt.plot(t, VVaY5, linewidth=3, label = "Phy-Taylor 2", color='red')
plt.plot(t, Y5_com, linewidth=3, label = "Ground Truth", color='black')
plt.xlabel("Time k", fontsize=20)
plt.ylabel(r'$\upsilon_2(k)$', fontsize=20)
plt.title("(g)", fontsize=25, fontweight='bold')
plt.legend()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.rc('legend',fontsize=20) 
plt.ylim([-14.5, 12])
plt.grid()
plt.xlim([500, 650])
plt.savefig('ce.pdf', dpi=0.1)
plt.show()

# %%
plt.figure(figsize= (9.5, 6))
plt.plot(t, VVbY6, linewidth=3, label = "FDNN", color='blue')
plt.plot(t, VVdY6, linewidth=3, label = "Phy-Taylor 1", color='lime')
plt.plot(t, VVaY6, linewidth=3, label = "Phy-Taylor 2", color='red')
plt.plot(t, Y6_com, linewidth=3, label = "Ground Truth", color='black')
plt.xlabel("Time k", fontsize=20)
plt.ylabel(r'$\upsilon_3(k)$', fontsize=20)
plt.title("(h)", fontsize=25, fontweight='bold')
plt.legend()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.rc('legend',fontsize=20) 
plt.ylim([-7.5, 6])
plt.grid()
plt.xlim([500, 650])
plt.savefig('cf.pdf', dpi=0.1)
plt.show()
